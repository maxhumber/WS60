# %%
from gazpacho import get, Soup

# %%
url = 'https://www.worldometers.info/coronavirus/'
html = get(url)

# %%
soup = Soup(html)

# %%
table = soup.find('table', {'id': 'main_table_countries_today'})

# %%
str(table)[:100]
# Out:
# '<table id="main_table_countries_today" class="table table-bordered table-hover main_table_countries"'

# %%
trs = table.find('tbody', mode='first').find('tr')

# %%
trs[:2]
# Out:
# [<tr style="">
#                                  <td style="font-weight: bold; font-size:15px; text-align:left;"><a class="mt_a" href="country/china/">China</a></td>
#                                  <td style="font-weight: bold; text-align:right">81,285</td>
#                                                                  <td style="font-weight: bold; text-align:right;background-color:#FFEEAA;">+67</td>
#                                  <td style="font-weight: bold; text-align:right;">3,287                                </td>
#
#                                                                  <td style="font-weight: bold; text-align:right;background-color:red; color:white">+6</td>
#                                  <td style="font-weight: bold; text-align:right">74,051</td>
#
#                                                                                                  <td style="text-align:right;font-weight:bold;">3,947</td>
#                                  <td style="font-weight: bold; text-align:right">1,235</td>
#                                  <td style="font-weight: bold; text-align:right">56</td>
#
#                              <td style="font-weight: bold; text-align:right">2</td>
#                              </tr>,
#  <tr style="">
#                                  <td style="font-weight: bold; font-size:15px; text-align:left;"><a class="mt_a" href="country/italy/">Italy</a></td>
#                                  <td style="font-weight: bold; text-align:right">74,386</td>
#                                                                  <td style="font-weight: bold; text-align:right;background-color:#FFEEAA;">+5,210</td>
#                                  <td style="font-weight: bold; text-align:right;">7,503                                </td>
#
#                                                                  <td style="font-weight: bold; text-align:right;background-color:red; color:white">+683</td>
#                                  <td style="font-weight: bold; text-align:right">9,362</td>
#
#                                                                                                  <td style="text-align:right;font-weight:bold;">57,521</td>
#                                  <td style="font-weight: bold; text-align:right">3,489</td>
#                                  <td style="font-weight: bold; text-align:right">1,230</td>
#
#                              <td style="font-weight: bold; text-align:right">124</td>
#                              </tr>]

# %%
tr = trs[0]

# %%
tr.find('td', mode='first').text
# Out:
# 'China'

# %%
tr.find('td')[1].text
# Out:
# '81,285'

# %%
def parse_tr(tr):
    country = tr.find('td', mode='first').text
    total = tr.find('td')[1].text
    total = float(total.replace(',', ''))
    return country, total

# %%
totals = [parse_tr(tr) for tr in trs]

# %%
totals[:10]
# Out:
# [('China', 81285.0),
#  ('Italy', 74386.0),
#  ('USA', 65797.0),
#  ('Spain', 49515.0),
#  ('Germany', 37323.0),
#  ('Iran', 27017.0),
#  ('France', 25233.0),
#  ('Switzerland', 10897.0),
#  ('UK', 9529.0),
#  ('S. Korea', 9137.0)]

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_total_health_expenditure_per_capita'
html = get(url)

# %%
soup = Soup(html)

# %%
import pandas as pd

# %%
table = soup.find('table', {'id': 'WHO'})[0]

# %%
who = pd.read_html(str(table))[0]

# %%
who = who.rename(columns={'Countries': 'country', '2015': 'health_expenditure'})
who = who[['country', 'health_expenditure']]

# %%
totals = pd.DataFrame(totals, columns=['country', 'cases'])

# %%
df = pd.merge(totals, who, on='country', how='left')

# %%
df
# Out:
#                     country    cases  health_expenditure
# 0                     China  81285.0               426.0
# 1                     Italy  74386.0              2700.0
# 2                       USA  65797.0                 NaN
# 3                     Spain  49515.0              2354.0
# 4                   Germany  37323.0              4592.0
# ..                      ...      ...                 ...
# 194        Papua New Guinea      1.0                77.0
# 195  St. Vincent Grenadines      1.0                 NaN
# 196                 Somalia      1.0                 NaN
# 197             Timor-Leste      1.0                72.0
# 198        Turks and Caicos      1.0                 NaN
#
# [199 rows x 3 columns]

# %% [markdown]
# ### Saving results

# %%
df.to_csv('../data/corona.csv', index=False)

# %%
df.head()
# Out:
#    country    cases  health_expenditure
# 0    China  81285.0               426.0
# 1    Italy  74386.0              2700.0
# 2      USA  65797.0                 NaN
# 3    Spain  49515.0              2354.0
# 4  Germany  37323.0              4592.0

# %%
df['date_fetched'] = pd.Timestamp('today')

# %%
df.head()
# Out:
#    country    cases  health_expenditure               date_fetched
# 0    China  81285.0               426.0 2020-03-25 20:38:44.549337
# 1    Italy  74386.0              2700.0 2020-03-25 20:38:44.549337
# 2      USA  65797.0                 NaN 2020-03-25 20:38:44.549337
# 3    Spain  49515.0              2354.0 2020-03-25 20:38:44.549337
# 4  Germany  37323.0              4592.0 2020-03-25 20:38:44.549337

# %%
import sqlite3

con = sqlite3.connect('../data/corona.db')

df.to_sql('corona', con, index=False, if_exists='append')

# %%
pd.read_sql('''
    select 
    * 
    from corona
    where cases > 1000
    order by health_expenditure desc
''', con)
# Out:
#         country    cases  health_expenditure                date_fetched
# 0   Switzerland   3939.0              9818.0  2020-03-19 10:15:17.678212
# 1   Switzerland  10897.0              9818.0  2020-03-25 20:38:44.549337
# 2        Norway   1706.0              7464.0  2020-03-19 10:15:17.678212
# 3        Norway   3084.0              7464.0  2020-03-25 20:38:44.549337
# 4    Luxembourg   1333.0              6236.0  2020-03-25 20:38:44.549337
# 5        Sweden   1423.0              5600.0  2020-03-19 10:15:17.678212
# 6        Sweden   2526.0              5600.0  2020-03-25 20:38:44.549337
# 7       Denmark   1132.0              5497.0  2020-03-19 10:15:17.678212
# 8       Denmark   1724.0              5497.0  2020-03-25 20:38:44.549337
# 9     Australia   2676.0              4934.0  2020-03-25 20:38:44.549337
# 10      Ireland   1564.0              4757.0  2020-03-25 20:38:44.549337
# 11  Netherlands   2460.0              4746.0  2020-03-19 10:15:17.678212
# 12  Netherlands   6412.0              4746.0  2020-03-25 20:38:44.549337
# 13      Germany  13632.0              4592.0  2020-03-19 10:15:17.678212
# 14      Germany  37323.0              4592.0  2020-03-25 20:38:44.549337
# 15      Austria   1843.0              4536.0  2020-03-19 10:15:17.678212
# 16      Austria   5588.0              4536.0  2020-03-25 20:38:44.549337
# 17       Canada   3409.0              4508.0  2020-03-25 20:38:44.549337
# 18      Belgium   1795.0              4228.0  2020-03-19 10:15:17.678212
# 19      Belgium   4937.0              4228.0  2020-03-25 20:38:44.549337
# 20       France   9134.0              4026.0  2020-03-19 10:15:17.678212
# 21       France  25233.0              4026.0  2020-03-25 20:38:44.549337
# 22        Japan   1307.0              3733.0  2020-03-25 20:38:44.549337
# 23       Israel   2369.0              2756.0  2020-03-25 20:38:44.549337
# 24        Italy  35713.0              2700.0  2020-03-19 10:15:17.678212
# 25        Italy  74386.0              2700.0  2020-03-25 20:38:44.549337
# 26        Spain  17147.0              2354.0  2020-03-19 10:15:17.678212
# 27        Spain  49515.0              2354.0  2020-03-25 20:38:44.549337
# 28     Portugal   2995.0              1722.0  2020-03-25 20:38:44.549337
# 29        Chile   1142.0              1102.0  2020-03-25 20:38:44.549337
# 30       Poland   1051.0               797.0  2020-03-25 20:38:44.549337
# 31       Brazil   2554.0               780.0  2020-03-25 20:38:44.549337
# 32      Ecuador   1211.0               530.0  2020-03-25 20:38:44.549337
# 33       Turkey   2433.0               455.0  2020-03-25 20:38:44.549337
# 34        China  80928.0               426.0  2020-03-19 10:15:17.678212
# 35        China  81285.0               426.0  2020-03-25 20:38:44.549337
# 36     Malaysia   1796.0               386.0  2020-03-25 20:38:44.549337
# 37     Pakistan   1063.0                38.0  2020-03-25 20:38:44.549337
# 38         Iran  18407.0                 NaN  2020-03-19 10:15:17.678212
# 39          USA   9486.0                 NaN  2020-03-19 10:15:17.678212
# 40     S. Korea   8565.0                 NaN  2020-03-19 10:15:17.678212
# 41           UK   2626.0                 NaN  2020-03-19 10:15:17.678212
# 42          USA  65797.0                 NaN  2020-03-25 20:38:44.549337
# 43         Iran  27017.0                 NaN  2020-03-25 20:38:44.549337
# 44           UK   9529.0                 NaN  2020-03-25 20:38:44.549337
# 45     S. Korea   9137.0                 NaN  2020-03-25 20:38:44.549337
# 46      Czechia   1654.0                 NaN  2020-03-25 20:38:44.549337

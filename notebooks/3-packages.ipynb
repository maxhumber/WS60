# %%
from gazpacho import get, Soup
from selenium.webdriver import Firefox
from selenium.webdriver.firefox.options import Options

# %%
url = 'https://pepy.tech/project/gazpacho'

# %%
html = get(url)

# %%
soup = Soup(html)

# %%
soup.find('tr', {'class': 'MuiTableRow-root'})

# %%
html
# Out:
# '<!doctype html><html lang="en"><head><meta charset="utf-8"/><link rel="shortcut icon" href="/favicon.ico"/><meta name="viewport" content="width=device-width,initial-scale=1"/><meta name="theme-color" content="#000000"/><link rel="manifest" href="/manifest.json"/><script type="text/javascript">window.NREUM||(NREUM={}),NREUM.init={privacy:{cookies_enabled:!0}},window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,(function(e){return r(t[n][1][e]||e)}),o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(t){}}var o,i=t("ee"),a=t(26),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,-1!==o.indexOf("dev")&&(c.dev=!0),-1!==o.indexOf("nr_dev")&&(c.nrDev=!0))}catch(t){}c.nrDev&&i.on("internal-error",(function(t){
# ...

# %% [markdown]
# ### Important
#
# If you're running this on your laptop you'll need a geckodriver from [here](https://github.com/mozilla/geckodriver/releases). Stick it in your path!
#
# You can check your path by running:

# %%
# !echo $PATH
# Out:
# /Users/max/opt/miniconda3/bin:/Users/max/opt/miniconda3/condabin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Apple/usr/bin

# %% [markdown]
# The process is a little bit different if you're running this on Binder versus on your laptop...
#
# Just make sure the Binder "switch" is flipped properly and you'll be good!

# %%
binder = True

# %%
options = Options()
options.headless = True
    
if binder:
    from webdriverdownloader import GeckoDriverDownloader
    gdd = GeckoDriverDownloader()
    gdd.download_and_install("v0.23.0")
    browser = Firefox(executable_path='/home/jovyan/bin/geckodriver', options=options)
else:
    browser = Firefox(executable_path='/usr/local/bin/geckodriver', options=options)

# %%
import time

for _ in range(2):
    browser.get(url)
    time.sleep(5)

# %%
html = browser.page_source
soup = Soup(html)
results = soup.find('tr', {'class': 'MuiTableRow-root'})

# %%
soup
# Out:
# <html lang="en"><head><meta charset="utf-8"><link rel="shortcut icon" href="/favicon.ico"><meta name="viewport" content="width=device-width,initial-scale=1"><meta name="theme-color" content="#000000"><link rel="manifest" href="/manifest.json"><script type="text/javascript" src="https://bam.eu01.nr-data.net/1/NRJS-fa55cf74c5ef98a2672?a=68765998&amp;sa=1&amp;v=1177.96a4d39&amp;t=Unnamed%20Transaction&amp;rst=865&amp;ck=1&amp;ref=https://pepy.tech/project/gazpacho&amp;be=149&amp;fe=525&amp;dc=375&amp;af=err,xhr,stn,ins,spa&amp;perf=%7B%22timing%22:%7B%22of%22:1614598994673,%22n%22:0,%22u%22:136,%22ue%22:144,%22f%22:0,%22dn%22:0,%22dne%22:0,%22c%22:0,%22s%22:0,%22ce%22:0,%22rq%22:4,%22rp%22:133,%22rpe%22:133,%22dl%22:136,%22di%22:368,%22ds%22:374,%22de%22:375,%22dc%22:524,%22l%22:524,%22le%22:525%7D,%22navigation%22:%7B%7D%7D&amp;fcp=353&amp;jsonp=NREUM.setToken"></script><script src="https://js-agent.newrelic.com/nr-spa-1177.min.js"></script><script async="" src="https://www.google-anal
# ...

# %%
results[1].find('td')[-1].text
# Out:
# '513'

# %%
results[2].find('td')[-1].text
# Out:
# '484'

# %% [markdown]
# ### Exercise

# %% [markdown]
# (homework 😉)
#
# Use [pepy.tech](https://pepy.tech) to scrape two of your favourite Python packages and plot the results!

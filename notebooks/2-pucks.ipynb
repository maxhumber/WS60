# %%
from gazpacho import get, Soup

# %%
url = 'https://www.capfriendly.com/'
html = get(url)

# %%
soup = Soup(html)

# %%
table = soup.find('table', {'id': 'ich'})

# %%
str(table)[:100]
# Out:
# '<table id="ich" class="sortablex tblcf index tbl sortable"><thead><tr class="column_head"><th class='

# %%
trs = table.find('tr', {'class': 'tmx'})

# %%
tr = trs[0]

# %%
tr.find('a', mode='first').text
# Out:
# 'Arizona Coyotes'

# %%
print(tr)
# Out:
# <tr class="odd tmx_2" data-sort-f="42359999" data-sort-d="29536625" data-sort-g="6100000" data-sort-inj2="5275000" data-sort-tch="85216068" data-sort-team="Arizona Coyotes" data-sort-rs="23" data-sort-spc="45" data-sort-inj="1" data-sort-ch="85089798" data-sort-ch2="3589798" data-sort-ch3="-81500000"><td class="tmx left" data-team="2" data-label="TEAM ▾"><span><img class="im_mid" style="height:15px;width:15px;margin-right:5px;margin-top:-2px;" alt="Arizona Coyotes" src="https://capfriendly-wlb8ng5.stackpathdns.com/assets/images/logos/arizona_coyotes.svg"><a href="/teams/coyotes">Arizona Coyotes</a></span><div class="r"><a title="Daily Cap Tracker" href="/teams/coyotes/cap-tracker"><img title="Daily Tracker" alt="Daily Tracker" style="margin-bottom:-3px;width:15px;height:15px" width="13" height="15" src="https://capfriendly-wlb8ng5.stackpathdns.com/assets/images/icons/teams/cal.svg" onerror="this.src='https://capfriendly-wlb8ng5.stackpathdns.com/assets/images/icons/teams/cal.png';this.onerror=null;"></a></div></td><td class="index_p index_projected tmx_s"></td><td data-label="ROSTER SIZE" class="tmx_s center index_projected">23</td><td data-label="CONTRACTS" class="tmx_s center index_projected">45/50</td><td class="index_p"></td><td data-label="FORWARDS" class="tmx_s left index_positional hide">$42,359,999 <span class="grey">(52%)</span></td><td data-label="DEFENSE" class="tmx_s left index_positional hide">$29,536,625 <span class="grey">(36.2%)</span></td><td data-label="GOALIES" class="tmx_s left index_positional hide">$6,100,000 <span class="grey">(7.5%)</span></td><td data-label="INJURIES" class="tmx_s left index_positional hide">$5,275,000 <span class="grey">(6.5%)</span></td><td data-label="TODAYS CAP HIT" class="tmx_s left index_positional hide">$85,216,068</td><td data-label="FINAL CAP HIT" class="tmx_s left index_projected"><span class="num" data-num="85089798">$85,089,798</span></td><td data-label="LTIR USED" class="tmx_s left index_projected"><span class="num" data-num="3589798">$3,589,798</span></td><td data-label="FINAL CAP SPACE" class="tmx_s left index_projected"><span class="num" data-num="0">$0</span></td></tr>

# %%
tr.find('td', {'data-label': 'FINAL CAP HIT'}, strict=True).text
# Out:
# '$85,089,798'

# %%
def parse_tr(tr):
    team = tr.find('a', mode='first').text
    cap = tr.find('td', {'data-label': 'FINAL CAP HIT'}, strict=True).text
    cap = float(cap.replace(',', '').replace('$', ''))
    return team, cap

# %%
cap_hits = [parse_tr(tr) for tr in trs]

# %%
url = 'https://www.hockey-reference.com/leagues/NHL_2020_standings.html'
html = get(url)

# %%
soup = Soup(html)

# %%
import pandas as pd

# %%
east = pd.read_html(str(soup.find('table')[0]))[0]
west = pd.read_html(str(soup.find('table')[1]))[0]

# %%
df = pd.concat([east, west])[['Unnamed: 0', 'GP', 'W']].reset_index(drop=True)

# %%
df['W'] = df['W'].apply(pd.to_numeric, errors='coerce')
wins = df.dropna()
wins = wins.rename(columns={'Unnamed: 0': 'Team'})

# %%
cap_hits = pd.DataFrame(cap_hits, columns=['Team', 'spend'])
df = pd.merge(wins, cap_hits, on='Team', how='left')
df['mpw'] = round(df['spend'] / df['W'] / 1_000_000, 2)
df.sort_values('mpw', ascending=True)
# Out:
#                      Team  GP     W       spend   mpw
# 17     Colorado Avalanche  70  42.0  76067463.0  1.81
# 0           Boston Bruins  70  44.0  81653080.0  1.86
# 1     Tampa Bay Lightning  70  43.0  80238349.0  1.87
# 16        St. Louis Blues  71  42.0  83216941.0  1.98
# 8     Washington Capitals  69  41.0  81564505.0  1.99
# 9     Philadelphia Flyers  69  41.0  82693252.0  2.02
# 10    Pittsburgh Penguins  69  40.0  81786224.0  2.04
# 19          Winnipeg Jets  71  37.0  77777881.0  2.10
# 14       New York Rangers  70  37.0  77613415.0  2.10
# 23   Vegas Golden Knights  71  39.0  81707634.0  2.10
# 11    Carolina Hurricanes  68  38.0  82410912.0  2.17
# 24        Edmonton Oilers  71  37.0  81203351.0  2.19
# 18           Dallas Stars  69  37.0  82023704.0  2.22
# 13     New York Islanders  68  35.0  78397298.0  2.24
# 21         Minnesota Wild  69  35.0  78572348.0  2.24
# 25         Calgary Flames  70  36.0  80849721.0  2.25
# 20    Nashville Predators  69  35.0  79117103.0  2.26
# 12  Columbus Blue Jackets  70  33.0  76432899.0  2.32
# 3        Florida Panthers  69  35.0  81225935.0  2.32
# 26      Vancouver Canucks  69  36.0  83799550.0  2.33
# 4      Montreal Canadiens  71  31.0  76960206.0  2.48
# 29      Los Angeles Kings  70  29.0  74508673.0  2.57
# 22     Chicago Blackhawks  70  32.0  82524710.0  2.58
# 27        Arizona Coyotes  70  33.0  85089798.0  2.58
# 15      New Jersey Devils  69  28.0  72724318.0  2.60
# 2     Toronto Maple Leafs  70  36.0  95178332.0  2.64
# 28          Anaheim Ducks  71  29.0  78692637.0  2.71
# 5          Buffalo Sabres  69  30.0  82803567.0  2.76
# 30        San Jose Sharks  70  29.0  81010454.0  2.79
# 6         Ottawa Senators  71  25.0  74319369.0  2.97
# 7       Detroit Red Wings  71  17.0  79968736.0  4.70

# %%
from IPython.display import HTML
HTML('<img src="https://media.giphy.com/media/oOX5qIDkzDjeo/giphy.gif">')
# Out:
# <img src="https://media.giphy.com/media/oOX5qIDkzDjeo/giphy.gif">

# %% [markdown]
# ### Saving results

# %%
df.to_csv('../data/mpw.csv', index=False)

# %%
df.head()
# Out:
#                   Team  GP     W       spend   mpw
# 0        Boston Bruins  70  44.0  81653080.0  1.86
# 1  Tampa Bay Lightning  70  43.0  80238349.0  1.87
# 2  Toronto Maple Leafs  70  36.0  95178332.0  2.64
# 3     Florida Panthers  69  35.0  81225935.0  2.32
# 4   Montreal Canadiens  71  31.0  76960206.0  2.48

# %%
df['date_fetched'] = pd.Timestamp('today')

# %%
df.head()
# Out:
#                   Team  GP     W       spend   mpw               date_fetched
# 0        Boston Bruins  70  44.0  81653080.0  1.86 2020-08-12 13:00:12.128263
# 1  Tampa Bay Lightning  70  43.0  80238349.0  1.87 2020-08-12 13:00:12.128263
# 2  Toronto Maple Leafs  70  36.0  95178332.0  2.64 2020-08-12 13:00:12.128263
# 3     Florida Panthers  69  35.0  81225935.0  2.32 2020-08-12 13:00:12.128263
# 4   Montreal Canadiens  71  31.0  76960206.0  2.48 2020-08-12 13:00:12.128263

# %%
import sqlite3

con = sqlite3.connect('../data/mpw.db')

df.to_sql('teams', con, index=False, if_exists='append')

# %%
pd.read_sql('''
    select 
    * 
    from teams 
    where mpw > 2 and W < 41
    order by mpw desc
''', con)
# Out:
#                      Team  GP     W       spend   mpw  \
# 0       Detroit Red Wings  71  17.0  79968736.0  4.70
# 1       Detroit Red Wings  71  17.0  79968736.0  4.70
# 2         Ottawa Senators  71  25.0  74319369.0  2.97
# 3         Ottawa Senators  71  25.0  74319369.0  2.97
# 4         San Jose Sharks  70  29.0  81010454.0  2.79
# 5         San Jose Sharks  70  29.0  81010454.0  2.79
# 6          Buffalo Sabres  69  30.0  82803567.0  2.76
# 7          Buffalo Sabres  69  30.0  82803567.0  2.76
# 8           Anaheim Ducks  71  29.0  78692637.0  2.71
# 9           Anaheim Ducks  71  29.0  78692637.0  2.71
# 10    Toronto Maple Leafs  70  36.0  95178332.0  2.64
# 11    Toronto Maple Leafs  70  36.0  95178332.0  2.64
# 12      New Jersey Devils  69  28.0  72724318.0  2.60
# 13      New Jersey Devils  69  28.0  72724318.0  2.60
# 14     Chicago Blackhawks  70  32.0  82524710.0  2.58
# 15        Arizona Coyotes  70  33.0  85089798.0  2.58
# 16     Chicago Blackhawks  70  32.0  82524710.0  2.58
# 17        Arizona Coyotes  70  33.0  85089798.0  2.58
# 18      Los Angeles Kings  70  29.0  74508673.0  2.57
# 19      Los Angeles Kings  70  29.0  74508673.0  2.57
# 20     Montreal Canadiens  71  31.0  76960206.0  2.48
# 21     Montreal Canadiens  71  31.0  76960206.0  2.48
# 22      Vancouver Canucks  69  36.0  83799550.0  2.33
# 23      Vancouver Canucks  69  36.0  83799550.0  2.33
# 24       Florida Panthers  69  35.0  81225935.0  2.32
# 25  Columbus Blue Jackets  70  33.0  76432899.0  2.32
# 26       Florida Panthers  69  35.0  81225935.0  2.32
# 27  Columbus Blue Jackets  70  33.0  76432899.0  2.32
# 28    Nashville Predators  69  35.0  79117103.0  2.26
# 29    Nashville Predators  69  35.0  79117103.0  2.26
# 30         Calgary Flames  70  36.0  80849721.0  2.25
# 31         Calgary Flames  70  36.0  80849721.0  2.25
# 32     New York Islanders  68  35.0  78397298.0  2.24
# 33         Minnesota Wild  69  35.0  78572348.0  2.24
# 34     New York Islanders  68  35.0  78397298.0  2.24
# 35         Minnesota Wild  69  35.0  78572348.0  2.24
# 36           Dallas Stars  69  37.0  82023704.0  2.22
# 37           Dallas Stars  69  37.0  82023704.0  2.22
# 38        Edmonton Oilers  71  37.0  81203351.0  2.19
# 39        Edmonton Oilers  71  37.0  81203351.0  2.19
# 40    Carolina Hurricanes  68  38.0  82410912.0  2.17
# 41    Carolina Hurricanes  68  38.0  82410912.0  2.17
# 42       New York Rangers  70  37.0  77613415.0  2.10
# 43          Winnipeg Jets  71  37.0  77777881.0  2.10
# 44   Vegas Golden Knights  71  39.0  81707634.0  2.10
# 45       New York Rangers  70  37.0  77613415.0  2.10
# 46          Winnipeg Jets  71  37.0  77777881.0  2.10
# 47   Vegas Golden Knights  71  39.0  81707634.0  2.10
# 48    Pittsburgh Penguins  69  40.0  81786224.0  2.04
# 49    Pittsburgh Penguins  69  40.0  81786224.0  2.04
#
#                   date_fetched
# 0   2020-08-11 15:14:34.722507
# 1   2020-08-12 13:00:12.128263
# 2   2020-08-11 15:14:34.722507
# 3   2020-08-12 13:00:12.128263
# 4   2020-08-11 15:14:34.722507
# 5   2020-08-12 13:00:12.128263
# 6   2020-08-11 15:14:34.722507
# 7   2020-08-12 13:00:12.128263
# 8   2020-08-11 15:14:34.722507
# 9   2020-08-12 13:00:12.128263
# 10  2020-08-11 15:14:34.722507
# 11  2020-08-12 13:00:12.128263
# 12  2020-08-11 15:14:34.722507
# 13  2020-08-12 13:00:12.128263
# 14  2020-08-11 15:14:34.722507
# 15  2020-08-11 15:14:34.722507
# 16  2020-08-12 13:00:12.128263
# 17  2020-08-12 13:00:12.128263
# 18  2020-08-11 15:14:34.722507
# 19  2020-08-12 13:00:12.128263
# 20  2020-08-11 15:14:34.722507
# 21  2020-08-12 13:00:12.128263
# 22  2020-08-11 15:14:34.722507
# 23  2020-08-12 13:00:12.128263
# 24  2020-08-11 15:14:34.722507
# 25  2020-08-11 15:14:34.722507
# 26  2020-08-12 13:00:12.128263
# 27  2020-08-12 13:00:12.128263
# 28  2020-08-11 15:14:34.722507
# 29  2020-08-12 13:00:12.128263
# 30  2020-08-11 15:14:34.722507
# 31  2020-08-12 13:00:12.128263
# 32  2020-08-11 15:14:34.722507
# 33  2020-08-11 15:14:34.722507
# 34  2020-08-12 13:00:12.128263
# 35  2020-08-12 13:00:12.128263
# 36  2020-08-11 15:14:34.722507
# 37  2020-08-12 13:00:12.128263
# 38  2020-08-11 15:14:34.722507
# 39  2020-08-12 13:00:12.128263
# 40  2020-08-11 15:14:34.722507
# 41  2020-08-12 13:00:12.128263
# 42  2020-08-11 15:14:34.722507
# 43  2020-08-11 15:14:34.722507
# 44  2020-08-11 15:14:34.722507
# 45  2020-08-12 13:00:12.128263
# 46  2020-08-12 13:00:12.128263
# 47  2020-08-12 13:00:12.128263
# 48  2020-08-11 15:14:34.722507
# 49  2020-08-12 13:00:12.128263

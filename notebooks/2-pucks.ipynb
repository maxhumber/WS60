# %%
from gazpacho import get, Soup
import pandas as pd

# %% [markdown]
# ### Money

# %%
url = 'https://www.capfriendly.com/archive/2021'
html = get(url)

# %%
soup = Soup(html)

# %%
table = soup.find('table', {'id': 'ich'})

# %%
str(table)[:100]
# Out:
# '<table id="ich" class="sortablex tblcf tbl index"><thead><tr class="column_head"><th align="left" st'

# %%
trs = table.find('tr', {'class': 'tmx'})

# %%
tr = trs[0]

# %%
tr.find('a', mode='first').text
# Out:
# 'Winnipeg Jets'

# %%
print(tr)
# Out:
# <tr class="odd tmx_30"><td class="tmx" data-team="30" data-label="TEAM ▾" align="left"><span><a href="/teams/cap-tracker/jets/2021"><img class="im_mid" style="height:20px;width:20px;margin-right:5px;margin-top:-2px;" alt="Winnipeg Jets" src="https://capfriendly-wlb8ng5.stackpathdns.com/assets/images/logos/winnipeg_jets.svg">Winnipeg Jets</a></span></td><td data-label="FINAL CAP HIT" class="tmx_s" align="left"><span class="num" data-num="84372152">$84,372,152</span></td><td data-label="LTIR USED" class="tmx_s" align="left"><span class="num" data-num="2872151">$2,872,151</span></td><td data-label="FINAL CAP SPACE" class="tmx_s" align="left"><span class="num" data-num="0">$0</span></td></tr>

# %%
tr.find('td', {'data-label': 'FINAL CAP HIT'}, partial=False).text
# Out:
# '$84,372,152'

# %%
def parse_tr(tr):
    team = tr.find('a', mode='first').text
    cap = tr.find('td', {'data-label': 'FINAL CAP HIT'}, partial=False).text
    cap = float(cap.replace(',', '').replace('$', ''))
    return team, cap

# %%
cap_hits = [parse_tr(tr) for tr in trs]

# %%
cap_hits = pd.DataFrame(cap_hits, columns=['Team', 'spend'])

# %% [markdown]
# ### Standings

# %%
url = 'https://www.hockey-reference.com/leagues/NHL_2021.html'

# %%
df = pd.read_html(url)[0]

# %%
df['PTS%'] = df['PTS%'].apply(pd.to_numeric, errors='coerce')
df = df.dropna(subset=["PTS%"])
df = df.rename(columns={'Unnamed: 0': 'Team'})
df = df.sort_values("PTS%", ascending = False)

# %%
df = pd.merge(df, cap_hits, on='Team', how='left')
df["efficiency"] = df["spend"] / 1_000_000 / df["PTS%"]

# %%
df.sort_values("efficiency")
# Out:
#                      Team  GP   W   L  OL PTS   PTS%   GF   GA    SRS    SOS  \
# 15       New York Rangers  56  27  23   6  60  0.536  177  157   0.31  -0.05
# 18    Philadelphia Flyers  56  25  23   8  58  0.518  163  201  -0.59   0.08
# 16           Dallas Stars  56  23  19  14  60  0.536  158  154   0.06  -0.01
# 22        Ottawa Senators  56  23  28   5  51  0.455  157  190  -0.51   0.08
# 20         Calgary Flames  56  26  27   3  55  0.491  156  161  -0.08   0.01
# 24      Los Angeles Kings  56  21  28   7  49  0.438  143  170  -0.42   0.06
# 21        Arizona Coyotes  56  24  26   6  54  0.482  153  176  -0.36   0.05
# 27      Detroit Red Wings  56  19  27  10  48  0.429  127  171  -0.69   0.10
# 19     Chicago Blackhawks  56  24  25   7  55  0.491  161  186  -0.39   0.06
# 28      New Jersey Devils  56  19  30   7  45  0.402  145  194  -0.77   0.11
# 25        San Jose Sharks  56  21  28   7  49  0.438  151  199  -0.75   0.11
# 26  Columbus Blue Jackets  56  18  26  12  48  0.429  137  187  -0.78   0.11
# 23      Vancouver Canucks  56  23  29   4  50  0.446  151  188  -0.56   0.10
# 29          Anaheim Ducks  56  17  30   9  43  0.384  126  179  -0.83   0.12
# 30         Buffalo Sabres  56  15  34   7  37  0.330  138  199  -0.95   0.14
# 0     Colorado Avalanche*  56  39  13   4  82  0.732  197  133   1.00  -0.14
# 1   Vegas Golden Knights*  56  40  14   2  82  0.732  191  124   1.05  -0.15
# 2    Carolina Hurricanes*  56  36  12   8  80  0.714  179  136   0.67  -0.10
# 3       Florida Panthers*  56  37  14   5  79  0.705  189  153   0.56  -0.08
# 4    Pittsburgh Penguins*  56  37  16   3  77  0.688  196  156   0.62  -0.09
# 5    Washington Capitals*  56  36  15   5  77  0.688  191  163   0.44  -0.06
# 6    Toronto Maple Leafs*  56  35  14   7  77  0.688  187  148   0.60  -0.10
# 7    Tampa Bay Lightning*  56  36  17   3  75  0.670  181  147   0.53  -0.08
# 8         Minnesota Wild*  56  35  16   5  75  0.670  181  160   0.33  -0.05
# 9          Boston Bruins*  56  33  16   7  73  0.652  168  136   0.50  -0.07
# 10       Edmonton Oilers*  56  35  19   2  72  0.643  183  154   0.44  -0.08
# 11    New York Islanders*  56  32  17   7  71  0.634  156  128   0.44  -0.06
# 12   Nashville Predators*  56  31  23   2  64  0.571  156  154   0.03   0.00
# 13         Winnipeg Jets*  56  30  23   3  63  0.563  170  154   0.25  -0.04
# 14       St. Louis Blues*  56  27  20   9  63  0.563  169  170  -0.02   0.00
# 17    Montreal Canadiens*  56  24  21  11  59  0.527  159  168  -0.14   0.02
#
#     RPt%  RW     RgRec RgPt%       spend  efficiency
# 15  .491  24   24-23-9  .509  76041380.0  141.868246
# 18  .455  17  17-23-16  .446  80631201.0  155.658689
# 16  .446  17  17-19-20  .482  84690956.0  158.005515
# 22  .402  18  18-28-10  .411  72262575.0  158.818846
# 20  .464  22   22-27-7  .455  80767183.0  164.495281
# 24  .375  19   19-28-9  .420  72360188.0  165.205909
# 21  .420  19  19-26-11  .438  80575270.0  167.168610
# 27  .348  16  16-27-13  .402  73888274.0  172.233739
# 19  .429  15  15-25-16  .411  85938963.0  175.028438
# 28  .384  15  15-30-11  .366  70916114.0  176.408244
# 25  .357  15  15-28-13  .384  79964663.0  182.567724
# 26  .321  12  12-26-18  .375  79832027.0  186.088641
# 23  .393  17  17-29-10  .393  86009407.0  192.846204
# 29  .304  11  11-30-15  .330  85678806.0  223.121891
# 30  .259  11  11-34-11  .295  80743186.0  244.676321
# 0   .705  35   35-13-8  .696         NaN         NaN
# 1   .723  30  30-14-12  .643         NaN         NaN
# 2   .625  27  27-12-17  .634         NaN         NaN
# 3   .670  26  26-14-16  .607         NaN         NaN
# 4   .643  29  29-16-11  .616         NaN         NaN
# 5   .634  29  29-15-12  .625         NaN         NaN
# 6   .616  29  29-14-13  .634         NaN         NaN
# 7   .652  29  29-17-10  .607         NaN         NaN
# 8   .625  27  27-16-13  .598         NaN         NaN
# 9   .571  25  25-16-15  .580         NaN         NaN
# 10  .625  31   31-19-6  .607         NaN         NaN
# 11  .563  24  24-17-15  .562         NaN         NaN
# 12  .509  21  21-23-12  .482         NaN         NaN
# 13  .554  24   24-23-9  .509         NaN         NaN
# 14  .491  19  19-20-17  .491         NaN         NaN
# 17  .446  20  20-21-15  .491         NaN         NaN

# %% [markdown]
# ### Saving results

# %%
df.to_csv('../data/efficiency.csv', index=False)

# %%
df.head()
# Out:
#                     Team  GP   W   L OL PTS   PTS%   GF   GA   SRS    SOS  \
# 0    Colorado Avalanche*  56  39  13  4  82  0.732  197  133  1.00  -0.14
# 1  Vegas Golden Knights*  56  40  14  2  82  0.732  191  124  1.05  -0.15
# 2   Carolina Hurricanes*  56  36  12  8  80  0.714  179  136  0.67  -0.10
# 3      Florida Panthers*  56  37  14  5  79  0.705  189  153  0.56  -0.08
# 4   Pittsburgh Penguins*  56  37  16  3  77  0.688  196  156  0.62  -0.09
#
#    RPt%  RW     RgRec RgPt%  spend  efficiency
# 0  .705  35   35-13-8  .696    NaN         NaN
# 1  .723  30  30-14-12  .643    NaN         NaN
# 2  .625  27  27-12-17  .634    NaN         NaN
# 3  .670  26  26-14-16  .607    NaN         NaN
# 4  .643  29  29-16-11  .616    NaN         NaN

# %%
df['date_fetched'] = pd.Timestamp('today')

# %%
df.head()
# Out:
#                     Team  GP   W   L OL PTS   PTS%   GF   GA   SRS    SOS  \
# 0    Colorado Avalanche*  56  39  13  4  82  0.732  197  133  1.00  -0.14
# 1  Vegas Golden Knights*  56  40  14  2  82  0.732  191  124  1.05  -0.15
# 2   Carolina Hurricanes*  56  36  12  8  80  0.714  179  136  0.67  -0.10
# 3      Florida Panthers*  56  37  14  5  79  0.705  189  153  0.56  -0.08
# 4   Pittsburgh Penguins*  56  37  16  3  77  0.688  196  156  0.62  -0.09
#
#    RPt%  RW     RgRec RgPt%  spend  efficiency               date_fetched
# 0  .705  35   35-13-8  .696    NaN         NaN 2021-10-14 13:26:49.786453
# 1  .723  30  30-14-12  .643    NaN         NaN 2021-10-14 13:26:49.786453
# 2  .625  27  27-12-17  .634    NaN         NaN 2021-10-14 13:26:49.786453
# 3  .670  26  26-14-16  .607    NaN         NaN 2021-10-14 13:26:49.786453
# 4  .643  29  29-16-11  .616    NaN         NaN 2021-10-14 13:26:49.786453

# %%
import sqlite3

con = sqlite3.connect('../data/efficiency.db')

df.to_sql('teams', con, index=False, if_exists='append')

# %%
pd.read_sql('''
    select 
    * 
    from teams 
    where efficiency < 150
    order by efficiency
''', con)
# Out:
#                     Team  GP   W   L OL PTS   PTS%   GF   GA    SRS    SOS  \
# 0    Toronto Maple Leafs  22  16   4  2  34  0.773   78   55   0.85  -0.20
# 1       Florida Panthers  20  13   4  3  29  0.725   65   57   0.29  -0.11
# 2   Vegas Golden Knights  17  12   4  1  25  0.735   51   36   0.72  -0.16
# 3    Philadelphia Flyers  18  11   4  3  25  0.694   61   54   0.35  -0.04
# 4          Boston Bruins  19  12   5  2  26  0.684   59   50   0.53   0.05
# 5    Carolina Hurricanes  20  13   6  1  27  0.675   69   56   0.85   0.20
# 6         Minnesota Wild  18  12   6  0  24  0.667   57   44   0.73   0.01
# 7          Winnipeg Jets  20  13   6  1  27  0.675   69   53   0.55  -0.25
# 8     Colorado Avalanche  18  11   6  1  23  0.639   55   42   0.82   0.10
# 9    Washington Capitals  21  12   5  4  28  0.667   73   69   0.03  -0.16
# 10   Tampa Bay Lightning  19  14   4  1  29  0.763   69   39   1.53  -0.05
# 11     Los Angeles Kings  20   9   7  4  22  0.550   60   56   0.38   0.18
# 12    Montreal Canadiens  20   9   6  5  23  0.575   65   60   0.16  -0.09
# 13    New York Islanders  21  11   6  4  26  0.619   56   49   0.28  -0.06
# 14    Chicago Blackhawks  23  12   7  4  28  0.609   73   68   0.00  -0.21
# 15       Edmonton Oilers  23  14   9  0  28  0.609   79   69   0.43  -0.01
# 16      New York Rangers  56  27  23  6  60  0.536  177  157   0.31  -0.05
# 17      New York Rangers  56  27  23  6  60  0.536  177  157   0.31  -0.05
# 18   Pittsburgh Penguins  20  11   8  1  23  0.575   60   65  -0.08   0.17
#
#     RPt%  RW    RgRec RgPt%       spend  efficiency  \
# 0   .727  14   14-4-4  .727  82812722.0  107.131594
# 1   .675   9    9-4-7  .625  78373558.0  108.101459
# 2   .735  10   10-4-3  .676  82163798.0  111.787480
# 3   .667   9    9-4-5  .639  80375446.0  115.814764
# 4   .579   7    7-5-7  .553  79332810.0  115.983640
# 5   .550   8    8-6-6  .550  78830512.0  116.785944
# 6   .667   8    8-6-4  .556  80900154.0  121.289586
# 7   .675   9    9-6-5  .575  83532360.0  123.751644
# 8   .611  10   10-6-2  .611  80849033.0  126.524308
# 9   .595  10   10-5-6  .619  85516834.0  128.211145
# 10  .737  13   13-4-2  .737  98196125.0  128.697412
# 11  .450   8    8-7-5  .525  72165528.0  131.210051
# 12  .500   9    9-6-5  .575  80542193.0  140.073379
# 13  .548  11   11-6-4  .619  86715252.0  140.089260
# 14  .543   7    7-7-9  .500  85417864.0  140.259218
# 15  .609  13   13-9-1  .587  85783331.0  140.859328
# 16  .491  24  24-23-9  .509  76041380.0  141.868246
# 17  .491  24  24-23-9  .509  76041380.0  141.868246
# 18  .475   4    4-8-8  .400  82270132.0  143.078490
#
#                   date_fetched
# 0   2021-03-01 06:40:37.743832
# 1   2021-03-01 06:40:37.743832
# 2   2021-03-01 06:40:37.743832
# 3   2021-03-01 06:40:37.743832
# 4   2021-03-01 06:40:37.743832
# 5   2021-03-01 06:40:37.743832
# 6   2021-03-01 06:40:37.743832
# 7   2021-03-01 06:40:37.743832
# 8   2021-03-01 06:40:37.743832
# 9   2021-03-01 06:40:37.743832
# 10  2021-03-01 06:40:37.743832
# 11  2021-03-01 06:40:37.743832
# 12  2021-03-01 06:40:37.743832
# 13  2021-03-01 06:40:37.743832
# 14  2021-03-01 06:40:37.743832
# 15  2021-03-01 06:40:37.743832
# 16  2021-05-31 11:05:46.821571
# 17  2021-10-14 13:26:49.786453
# 18  2021-03-01 06:40:37.743832

# %%
from gazpacho import get, Soup
import pandas as pd

# %% [markdown]
# ### Money

# %%
url = 'https://www.capfriendly.com/archive/2022'
html = get(url)

# %%
soup = Soup(html)

# %%
table = soup.find('table', {'id': 'ich'})

# %%
str(table)[:100]
# Out:
# '<table id="ich" class="sortablex tblcf tbl index"><thead><tr class="column_head"><th class="left" st'

# %%
trs = table.find('tr', {'class': 'tmx'})

# %%
tr = trs[0]

# %%
tr.find('a', mode='first').text
# Out:
# 'Montreal Canadiens'

# %%
print(tr)
# Out:
# <tr class="odd tmx_16"><td class="tmx left" data-team="16" data-label="TEAM ▾"><span><a href="/teams/cap-tracker/canadiens/2022"><img class="im_mid" style="height:20px;width:20px;margin-right:5px;margin-top:-2px;" alt="Logo of the Montreal Canadiens" src="https://capfriendly-wlb8ng5.stackpathdns.com/assets/images/logos/montreal_canadiens.svg">Montreal Canadiens</a></span></td><td data-label="FINAL CAP HIT" class="tmx_s left"><span class="num" data-num="92493917">$92,493,917</span></td><td data-label="LTIR USED" class="tmx_s left"><span class="num" data-num="10993917">$10,993,917</span></td><td data-label="FINAL CAP SPACE" class="tmx_s left"><span class="num" data-num="0">$0</span></td></tr>

# %%
tr.find('td', {'data-label': 'FINAL CAP HIT'}, partial=False).text
# Out:
# '$92,493,917'

# %%
def parse_tr(tr):
    team = tr.find('a', mode='first').text
    cap = tr.find('td', {'data-label': 'FINAL CAP HIT'}, partial=False).text
    cap = float(cap.replace(',', '').replace('$', ''))
    return team, cap

# %%
cap_hits = [parse_tr(tr) for tr in trs]

# %%
cap_hits = pd.DataFrame(cap_hits, columns=['Team', 'spend'])

# %% [markdown]
# ### Standings

# %%
url = 'https://www.hockey-reference.com/leagues/NHL_2022.html'

# %%
df = pd.read_html(url)[0]

# %%
df['PTS%'] = df['PTS%'].apply(pd.to_numeric, errors='coerce')
df = df.dropna(subset=["PTS%"])
df = df.rename(columns={'Unnamed: 0': 'Team'})
df = df.sort_values("PTS%", ascending = False)

# %%
df = pd.merge(df, cap_hits, on='Team', how='left')
df["efficiency"] = df["spend"] / 1_000_000 / df["PTS%"]

# %%
df.sort_values("efficiency")
# Out:
#                      Team  GP   W   L  OL  PTS   PTS%   GF   GA    SRS    SOS  \
# 0        Florida Panthers  82  58  18   6  122  0.744  340  246   1.07  -0.08
# 4        New York Rangers  82  52  24   6  110  0.671  254  207   0.54  -0.03
# 1     Carolina Hurricanes  82  54  20   8  116  0.707  278  202   0.88  -0.05
# 2     Toronto Maple Leafs  82  54  21   7  115  0.701  315  253   0.69  -0.06
# 5           Boston Bruins  82  51  26   5  107  0.652  255  220   0.38  -0.05
# 3     Tampa Bay Lightning  82  51  23   8  110  0.671  287  233   0.64  -0.02
# 6     Pittsburgh Penguins  82  46  25  11  103  0.628  272  229   0.49  -0.04
# 7     Washington Capitals  82  44  26  12  100  0.610  275  245   0.35  -0.02
# 9   Columbus Blue Jackets  82  37  38   7   81  0.494  262  300  -0.44   0.02
# 10         Buffalo Sabres  82  32  39  11   75  0.457  232  290  -0.69   0.02
# 8      New York Islanders  82  37  35  10   84  0.512  231  237  -0.09  -0.02
# 11      Detroit Red Wings  82  32  40  10   74  0.451  230  312  -0.95   0.06
# 12        Ottawa Senators  82  33  42   7   73  0.445  227  266  -0.44   0.03
# 13      New Jersey Devils  82  27  46   9   63  0.384  248  307  -0.68   0.04
# 14    Philadelphia Flyers  82  25  46  11   61  0.372  211  298  -1.00   0.06
# 15     Montreal Canadiens  82  22  49  11   55  0.335  221  319  -1.15   0.05
#
#     RPt%  RW     RgRec RgPt%       spend  efficiency
# 0   .713  42  42-18-22  .646  82930085.0  111.465168
# 4   .628  44  44-24-14  .622  75108450.0  111.935097
# 1   .665  47  47-20-15  .665  83866550.0  118.623126
# 2   .646  45  45-21-16  .646  83761840.0  119.489073
# 5   .622  40  40-26-16  .585  80829990.0  123.972377
# 3   .640  39  39-23-20  .598  89214115.0  132.956952
# 6   .585  37  37-25-20  .573  83539221.0  133.024237
# 7   .524  35  35-26-21  .555  84839289.0  139.080802
# 9   .445  26  26-38-18  .427  70736371.0  143.191034
# 10  .390  25  25-39-18  .415  67574592.0  147.865628
# 8   .476  34  34-35-13  .494  79458296.0  155.191984
# 11  .384  21  21-40-21  .384  70262310.0  155.792262
# 12  .396  26  26-42-14  .402  70881426.0  159.284103
# 13  .341  19  19-46-17  .335  74146012.0  193.088573
# 14  .323  20  20-46-16  .341  84138714.0  226.179339
# 15  .262  16  16-49-17  .299  92493917.0  276.101245

# %% [markdown]
# ### Saving results

# %%
df.to_csv('../data/efficiency.csv', index=False)

# %%
df.head()
# Out:
#                   Team  GP   W   L OL  PTS   PTS%   GF   GA   SRS    SOS  \
# 0     Florida Panthers  82  58  18  6  122  0.744  340  246  1.07  -0.08
# 1  Carolina Hurricanes  82  54  20  8  116  0.707  278  202  0.88  -0.05
# 2  Toronto Maple Leafs  82  54  21  7  115  0.701  315  253  0.69  -0.06
# 3  Tampa Bay Lightning  82  51  23  8  110  0.671  287  233  0.64  -0.02
# 4     New York Rangers  82  52  24  6  110  0.671  254  207  0.54  -0.03
#
#    RPt%  RW     RgRec RgPt%       spend  efficiency
# 0  .713  42  42-18-22  .646  82930085.0  111.465168
# 1  .665  47  47-20-15  .665  83866550.0  118.623126
# 2  .646  45  45-21-16  .646  83761840.0  119.489073
# 3  .640  39  39-23-20  .598  89214115.0  132.956952
# 4  .628  44  44-24-14  .622  75108450.0  111.935097

# %%
df['date_fetched'] = pd.Timestamp('today')

# %%
df.head()
# Out:
#                   Team  GP   W   L OL  PTS   PTS%   GF   GA   SRS    SOS  \
# 0     Florida Panthers  82  58  18  6  122  0.744  340  246  1.07  -0.08
# 1  Carolina Hurricanes  82  54  20  8  116  0.707  278  202  0.88  -0.05
# 2  Toronto Maple Leafs  82  54  21  7  115  0.701  315  253  0.69  -0.06
# 3  Tampa Bay Lightning  82  51  23  8  110  0.671  287  233  0.64  -0.02
# 4     New York Rangers  82  52  24  6  110  0.671  254  207  0.54  -0.03
#
#    RPt%  RW     RgRec RgPt%       spend  efficiency               date_fetched
# 0  .713  42  42-18-22  .646  82930085.0  111.465168 2022-06-05 11:12:39.430977
# 1  .665  47  47-20-15  .665  83866550.0  118.623126 2022-06-05 11:12:39.430977
# 2  .646  45  45-21-16  .646  83761840.0  119.489073 2022-06-05 11:12:39.430977
# 3  .640  39  39-23-20  .598  89214115.0  132.956952 2022-06-05 11:12:39.430977
# 4  .628  44  44-24-14  .622  75108450.0  111.935097 2022-06-05 11:12:39.430977

# %%
import sqlite3

con = sqlite3.connect('../data/efficiency.db')

df.to_sql('teams', con, index=False, if_exists='append')
# Out:
# 16

# %%
pd.read_sql('''
    select 
    * 
    from teams 
    where efficiency < 150
    order by efficiency
''', con)
# Out:
#                      Team  GP   W   L  OL  PTS   PTS%   GF   GA    SRS    SOS  \
# 0     Toronto Maple Leafs  22  16   4   2   34  0.773   78   55   0.85  -0.20
# 1        Florida Panthers  20  13   4   3   29  0.725   65   57   0.29  -0.11
# 2        Florida Panthers  82  58  18   6  122  0.744  340  246   1.07  -0.08
# 3    Vegas Golden Knights  17  12   4   1   25  0.735   51   36   0.72  -0.16
# 4        New York Rangers  82  52  24   6  110  0.671  254  207   0.54  -0.03
# 5     Philadelphia Flyers  18  11   4   3   25  0.694   61   54   0.35  -0.04
# 6           Boston Bruins  19  12   5   2   26  0.684   59   50   0.53   0.05
# 7     Carolina Hurricanes  20  13   6   1   27  0.675   69   56   0.85   0.20
# 8     Carolina Hurricanes  82  54  20   8  116  0.707  278  202   0.88  -0.05
# 9     Toronto Maple Leafs  82  54  21   7  115  0.701  315  253   0.69  -0.06
# 10         Minnesota Wild  18  12   6   0   24  0.667   57   44   0.73   0.01
# 11          Winnipeg Jets  20  13   6   1   27  0.675   69   53   0.55  -0.25
# 12          Boston Bruins  82  51  26   5  107  0.652  255  220   0.38  -0.05
# 13     Colorado Avalanche  18  11   6   1   23  0.639   55   42   0.82   0.10
# 14    Washington Capitals  21  12   5   4   28  0.667   73   69   0.03  -0.16
# 15    Tampa Bay Lightning  19  14   4   1   29  0.763   69   39   1.53  -0.05
# 16      Los Angeles Kings  20   9   7   4   22  0.550   60   56   0.38   0.18
# 17    Tampa Bay Lightning  82  51  23   8  110  0.671  287  233   0.64  -0.02
# 18    Pittsburgh Penguins  82  46  25  11  103  0.628  272  229   0.49  -0.04
# 19    Washington Capitals  82  44  26  12  100  0.610  275  245   0.35  -0.02
# 20     Montreal Canadiens  20   9   6   5   23  0.575   65   60   0.16  -0.09
# 21     New York Islanders  21  11   6   4   26  0.619   56   49   0.28  -0.06
# 22     Chicago Blackhawks  23  12   7   4   28  0.609   73   68   0.00  -0.21
# 23        Edmonton Oilers  23  14   9   0   28  0.609   79   69   0.43  -0.01
# 24       New York Rangers  56  27  23   6   60  0.536  177  157   0.31  -0.05
# 25       New York Rangers  56  27  23   6   60  0.536  177  157   0.31  -0.05
# 26    Pittsburgh Penguins  20  11   8   1   23  0.575   60   65  -0.08   0.17
# 27  Columbus Blue Jackets  82  37  38   7   81  0.494  262  300  -0.44   0.02
# 28         Buffalo Sabres  82  32  39  11   75  0.457  232  290  -0.69   0.02
#
#     RPt%  RW     RgRec RgPt%       spend  efficiency  \
# 0   .727  14    14-4-4  .727  82812722.0  107.131594
# 1   .675   9     9-4-7  .625  78373558.0  108.101459
# 2   .713  42  42-18-22  .646  82930085.0  111.465168
# 3   .735  10    10-4-3  .676  82163798.0  111.787480
# 4   .628  44  44-24-14  .622  75108450.0  111.935097
# 5   .667   9     9-4-5  .639  80375446.0  115.814764
# 6   .579   7     7-5-7  .553  79332810.0  115.983640
# 7   .550   8     8-6-6  .550  78830512.0  116.785944
# 8   .665  47  47-20-15  .665  83866550.0  118.623126
# 9   .646  45  45-21-16  .646  83761840.0  119.489073
# 10  .667   8     8-6-4  .556  80900154.0  121.289586
# 11  .675   9     9-6-5  .575  83532360.0  123.751644
# 12  .622  40  40-26-16  .585  80829990.0  123.972377
# 13  .611  10    10-6-2  .611  80849033.0  126.524308
# 14  .595  10    10-5-6  .619  85516834.0  128.211145
# 15  .737  13    13-4-2  .737  98196125.0  128.697412
# 16  .450   8     8-7-5  .525  72165528.0  131.210051
# 17  .640  39  39-23-20  .598  89214115.0  132.956952
# 18  .585  37  37-25-20  .573  83539221.0  133.024237
# 19  .524  35  35-26-21  .555  84839289.0  139.080802
# 20  .500   9     9-6-5  .575  80542193.0  140.073379
# 21  .548  11    11-6-4  .619  86715252.0  140.089260
# 22  .543   7     7-7-9  .500  85417864.0  140.259218
# 23  .609  13    13-9-1  .587  85783331.0  140.859328
# 24  .491  24   24-23-9  .509  76041380.0  141.868246
# 25  .491  24   24-23-9  .509  76041380.0  141.868246
# 26  .475   4     4-8-8  .400  82270132.0  143.078490
# 27  .445  26  26-38-18  .427  70736371.0  143.191034
# 28  .390  25  25-39-18  .415  67574592.0  147.865628
#
#                   date_fetched
# 0   2021-03-01 06:40:37.743832
# 1   2021-03-01 06:40:37.743832
# 2   2022-06-05 11:12:39.430977
# 3   2021-03-01 06:40:37.743832
# 4   2022-06-05 11:12:39.430977
# 5   2021-03-01 06:40:37.743832
# 6   2021-03-01 06:40:37.743832
# 7   2021-03-01 06:40:37.743832
# 8   2022-06-05 11:12:39.430977
# 9   2022-06-05 11:12:39.430977
# 10  2021-03-01 06:40:37.743832
# 11  2021-03-01 06:40:37.743832
# 12  2022-06-05 11:12:39.430977
# 13  2021-03-01 06:40:37.743832
# 14  2021-03-01 06:40:37.743832
# 15  2021-03-01 06:40:37.743832
# 16  2021-03-01 06:40:37.743832
# 17  2022-06-05 11:12:39.430977
# 18  2022-06-05 11:12:39.430977
# 19  2022-06-05 11:12:39.430977
# 20  2021-03-01 06:40:37.743832
# 21  2021-03-01 06:40:37.743832
# 22  2021-03-01 06:40:37.743832
# 23  2021-03-01 06:40:37.743832
# 24  2021-05-31 11:05:46.821571
# 25  2021-10-14 13:26:49.786453
# 26  2021-03-01 06:40:37.743832
# 27  2022-06-05 11:12:39.430977
# 28  2022-06-05 11:12:39.430977

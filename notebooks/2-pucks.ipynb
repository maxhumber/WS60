# %%
from gazpacho import get, Soup
import pandas as pd

# %% [markdown]
# ### Money

# %%
url = 'https://www.capfriendly.com'
html = get(url)

# %%
soup = Soup(html)

# %%
table = soup.find('table', {'id': 'ich'})

# %%
str(table)[:100]
# Out:
# '<table id="ich" class="sortablex tblcf index tbl sortable"><thead><tr class="column_head"><th class='

# %%
trs = table.find('tr', {'class': 'tmx'})

# %%
tr = trs[0]

# %%
tr.find('a', mode='first').text
# Out:
# 'Tampa Bay Lightning'

# %%
print(tr)
# Out:
# <tr class="odd tmx_26" data-sort-f="45029166" data-sort-d="24600000" data-sort-g="10800000" data-sort-inj2="17712500" data-sort-tch="98141666" data-sort-team="Tampa Bay Lightning" data-sort-rs="20" data-sort-spc="45" data-sort-inj="4" data-sort-ch="98196125" data-sort-ch2="0" data-sort-ch3="1070500"><td class="tmx left" data-team="26" data-label="TEAM ▾"><span><img class="im_mid" style="height:15px;width:15px;margin-right:5px;margin-top:-2px;" alt="Tampa Bay Lightning" src="https://capfriendly-wlb8ng5.stackpathdns.com/assets/images/logos/tampa_bay_lightning.svg"><a href="/teams/lightning">Tampa Bay Lightning</a></span><div class="r"><a title="Daily Cap Tracker" href="/teams/lightning/cap-tracker"><img title="Daily Tracker" alt="Daily Tracker" style="margin-bottom:-3px;width:15px;height:15px" width="13" height="15" src="https://capfriendly-wlb8ng5.stackpathdns.com/assets/images/icons/teams/cal.svg" onerror="this.src='https://capfriendly-wlb8ng5.stackpathdns.com/assets/images/icons/teams/cal.png';this.onerror=null;"></a></div></td><td class="index_p index_projected tmx_s"></td><td data-label="ROSTER SIZE" class="tmx_s center index_projected">20/23</td><td data-label="CONTRACTS" class="tmx_s center index_projected">45/50</td><td data-label="INJURIES" class="tmx_s center index_projected"><div class="rel">4<div style="font-size:10px;left:20px;top:2px" class="q mr5 red abs" title="LTIR Salary Pool: $17,712,500 | LTIR P.Bonus Pool: $0"> LTIR</div></div></td><td class="index_p"></td><td data-label="FORWARDS" class="tmx_s left index_positional hide">$45,029,166 <span class="grey">(55.3%)</span></td><td data-label="DEFENSE" class="tmx_s left index_positional hide">$24,600,000 <span class="grey">(30.2%)</span></td><td data-label="GOALIES" class="tmx_s left index_positional hide">$10,800,000 <span class="grey">(13.3%)</span></td><td data-label="INJURIES" class="tmx_s left index_positional hide">$17,712,500 <span class="grey">(21.7%)</span></td><td data-label="TODAYS CAP HIT" class="tmx_s left index_positional hide">$98,141,666</td><td data-label="PROJECTED CAP HIT" class="tmx_s left index_projected">$98,196,125</td><td data-label="PROJECTED SPACE" class="tmx_s left index_projected">$0</td><td data-label="CURRENT SPACE" class="tmx_s left index_projected">$1,070,500 <span class="q red" title="This team is using LTIR and therefore the current cap space they have is estimated as the remaining amount of their LTIR salary pool. (This may be less if a player with earnable performance bonuses is recalled. See LTIR FAQ for more details)" style="font-size:10px;margin-top:2px">LTIR</span></td></tr>

# %%
tr.find('td', {'data-label': 'PROJECTED CAP HIT'}, partial=False).text
# Out:
# '$98,196,125'

# %%
def parse_tr(tr):
    team = tr.find('a', mode='first').text
    cap = tr.find('td', {'data-label': 'PROJECTED CAP HIT'}, partial=False).text
    cap = float(cap.replace(',', '').replace('$', ''))
    return team, cap

# %%
cap_hits = [parse_tr(tr) for tr in trs]

# %%
cap_hits = pd.DataFrame(cap_hits, columns=['Team', 'spend'])

# %% [markdown]
# ### Standings

# %%
url = 'https://www.hockey-reference.com/leagues/NHL_2021.html'

# %%
df = pd.read_html(url)[0]

# %%
df['PTS%'] = df['PTS%'].apply(pd.to_numeric, errors='coerce')
df = df.dropna(subset=["PTS%"])
df = df.rename(columns={'Unnamed: 0': 'Team'})
df = df.sort_values("PTS%", ascending = False)

# %%
df = pd.merge(df, cap_hits, on='Team', how='left')
df["efficiency"] = df["spend"] / 1_000_000 / df["PTS%"]

# %%
df.sort_values("efficiency")
# Out:
#                      Team  GP   W   L OL PTS   PTS%  GF  GA    SRS    SOS  \
# 0     Toronto Maple Leafs  22  16   4  2  34  0.773  78  55   0.85  -0.20
# 3        Florida Panthers  20  13   4  3  29  0.725  65  57   0.29  -0.11
# 2    Vegas Golden Knights  17  12   4  1  25  0.735  51  36   0.72  -0.16
# 4     Philadelphia Flyers  18  11   4  3  25  0.694  61  54   0.35  -0.04
# 5           Boston Bruins  19  12   5  2  26  0.684  59  50   0.53   0.05
# 6     Carolina Hurricanes  20  13   6  1  27  0.675  69  56   0.85   0.20
# 8          Minnesota Wild  18  12   6  0  24  0.667  57  44   0.73   0.01
# 7           Winnipeg Jets  20  13   6  1  27  0.675  69  53   0.55  -0.25
# 10     Colorado Avalanche  18  11   6  1  23  0.639  55  42   0.82   0.10
# 9     Washington Capitals  21  12   5  4  28  0.667  73  69   0.03  -0.16
# 1     Tampa Bay Lightning  19  14   4  1  29  0.763  69  39   1.53  -0.05
# 17      Los Angeles Kings  20   9   7  4  22  0.550  60  56   0.38   0.18
# 14     Montreal Canadiens  20   9   6  5  23  0.575  65  60   0.16  -0.09
# 11     New York Islanders  21  11   6  4  26  0.619  56  49   0.28  -0.06
# 13     Chicago Blackhawks  23  12   7  4  28  0.609  73  68   0.00  -0.21
# 12        Edmonton Oilers  23  14   9  0  28  0.609  79  69   0.43  -0.01
# 15    Pittsburgh Penguins  20  11   8  1  23  0.575  60  65  -0.08   0.17
# 22      New Jersey Devils  17   7   8  2  16  0.471  45  52  -0.44  -0.03
# 16        St. Louis Blues  21  11   8  2  24  0.571  67  67  -0.26  -0.26
# 19        Arizona Coyotes  21   9   9  3  21  0.500  56  64  -0.45  -0.07
# 20         Calgary Flames  22  10  10  2  22  0.500  58  65  -0.22   0.09
# 21    Nashville Predators  21  10  11  0  20  0.476  49  64  -0.72  -0.01
# 18           Dallas Stars  16   6   6  4  16  0.500  46  45   0.13   0.07
# 24       New York Rangers  19   7   9  3  17  0.447  50  52  -0.05   0.06
# 25        San Jose Sharks  18   7   9  2  16  0.444  53  71  -0.95   0.05
# 23  Columbus Blue Jackets  23   8  10  5  21  0.457  62  77  -0.65   0.01
# 27         Buffalo Sabres  19   6  10  3  15  0.395  44  57  -0.68   0.01
# 29      Detroit Red Wings  24   7  14  3  17  0.354  51  78  -1.02   0.11
# 26          Anaheim Ducks  21   6  10  5  17  0.405  42  61  -0.75   0.16
# 30        Ottawa Senators  23   7  15  1  15  0.326  61  91  -1.00   0.31
# 28      Vancouver Canucks  24   8  14  2  18  0.375  68  85  -0.61   0.10
#
#     RPt%  RW   RgRec RgPt%       spend  efficiency
# 0   .727  14  14-4-4  .727  82812722.0  107.131594
# 3   .675   9   9-4-7  .625  78373558.0  108.101459
# 2   .735  10  10-4-3  .676  82163798.0  111.787480
# 4   .667   9   9-4-5  .639  80375446.0  115.814764
# 5   .579   7   7-5-7  .553  79332810.0  115.983640
# 6   .550   8   8-6-6  .550  78830512.0  116.785944
# 8   .667   8   8-6-4  .556  80900154.0  121.289586
# 7   .675   9   9-6-5  .575  83532360.0  123.751644
# 10  .611  10  10-6-2  .611  80849033.0  126.524308
# 9   .595  10  10-5-6  .619  85516834.0  128.211145
# 1   .737  13  13-4-2  .737  98196125.0  128.697412
# 17  .450   8   8-7-5  .525  72165528.0  131.210051
# 14  .500   9   9-6-5  .575  80542193.0  140.073379
# 11  .548  11  11-6-4  .619  86715252.0  140.089260
# 13  .543   7   7-7-9  .500  85417864.0  140.259218
# 12  .609  13  13-9-1  .587  85783331.0  140.859328
# 15  .475   4   4-8-8  .400  82270132.0  143.078490
# 22  .471   5   5-8-4  .412  72487531.0  153.901340
# 16  .548   8   8-8-5  .500  90196348.0  157.962081
# 19  .429   7   7-9-5  .452  79410219.0  158.820438
# 20  .432   8  8-10-4  .455  81660179.0  163.320358
# 21  .452   7  7-11-3  .405  78504828.0  164.926109
# 18  .438   5   5-6-5  .469  83605654.0  167.211308
# 24  .368   5   5-9-5  .395  77221459.0  172.754942
# 25  .306   3   3-9-6  .333  77856876.0  175.353324
# 23  .370   7  7-10-6  .435  80430554.0  175.996836
# 27  .289   4  4-10-5  .342  81882926.0  207.298547
# 29  .292   6  6-14-4  .333  74377800.0  210.106780
# 26  .310   5  5-10-6  .381  85204855.0  210.382358
# 30  .283   4  4-15-4  .261  72212855.0  221.511825
# 28  .313   7  7-14-3  .354  85413976.0  227.770603

# %% [markdown]
# ### Saving results

# %%
df.to_csv('../data/efficiency.csv', index=False)

# %%
df.head()
# Out:
#                    Team  GP   W  L OL PTS   PTS%  GF  GA   SRS    SOS  RPt%  \
# 0   Toronto Maple Leafs  22  16  4  2  34  0.773  78  55  0.85  -0.20  .727
# 1   Tampa Bay Lightning  19  14  4  1  29  0.763  69  39  1.53  -0.05  .737
# 2  Vegas Golden Knights  17  12  4  1  25  0.735  51  36  0.72  -0.16  .735
# 3      Florida Panthers  20  13  4  3  29  0.725  65  57  0.29  -0.11  .675
# 4   Philadelphia Flyers  18  11  4  3  25  0.694  61  54  0.35  -0.04  .667
#
#    RW   RgRec RgPt%       spend  efficiency
# 0  14  14-4-4  .727  82812722.0  107.131594
# 1  13  13-4-2  .737  98196125.0  128.697412
# 2  10  10-4-3  .676  82163798.0  111.787480
# 3   9   9-4-7  .625  78373558.0  108.101459
# 4   9   9-4-5  .639  80375446.0  115.814764

# %%
df['date_fetched'] = pd.Timestamp('today')

# %%
df.head()
# Out:
#                    Team  GP   W  L OL PTS   PTS%  GF  GA   SRS    SOS  RPt%  \
# 0   Toronto Maple Leafs  22  16  4  2  34  0.773  78  55  0.85  -0.20  .727
# 1   Tampa Bay Lightning  19  14  4  1  29  0.763  69  39  1.53  -0.05  .737
# 2  Vegas Golden Knights  17  12  4  1  25  0.735  51  36  0.72  -0.16  .735
# 3      Florida Panthers  20  13  4  3  29  0.725  65  57  0.29  -0.11  .675
# 4   Philadelphia Flyers  18  11  4  3  25  0.694  61  54  0.35  -0.04  .667
#
#    RW   RgRec RgPt%       spend  efficiency               date_fetched
# 0  14  14-4-4  .727  82812722.0  107.131594 2021-03-01 06:40:37.743832
# 1  13  13-4-2  .737  98196125.0  128.697412 2021-03-01 06:40:37.743832
# 2  10  10-4-3  .676  82163798.0  111.787480 2021-03-01 06:40:37.743832
# 3   9   9-4-7  .625  78373558.0  108.101459 2021-03-01 06:40:37.743832
# 4   9   9-4-5  .639  80375446.0  115.814764 2021-03-01 06:40:37.743832

# %%
import sqlite3

con = sqlite3.connect('../data/efficiency.db')

df.to_sql('teams', con, index=False, if_exists='append')

# %%
pd.read_sql('''
    select 
    * 
    from teams 
    where efficiency < 150
    order by efficiency
''', con)
# Out:
#                     Team  GP   W  L OL PTS   PTS%  GF  GA    SRS    SOS  RPt%  \
# 0    Toronto Maple Leafs  22  16  4  2  34  0.773  78  55   0.85  -0.20  .727
# 1       Florida Panthers  20  13  4  3  29  0.725  65  57   0.29  -0.11  .675
# 2   Vegas Golden Knights  17  12  4  1  25  0.735  51  36   0.72  -0.16  .735
# 3    Philadelphia Flyers  18  11  4  3  25  0.694  61  54   0.35  -0.04  .667
# 4          Boston Bruins  19  12  5  2  26  0.684  59  50   0.53   0.05  .579
# 5    Carolina Hurricanes  20  13  6  1  27  0.675  69  56   0.85   0.20  .550
# 6         Minnesota Wild  18  12  6  0  24  0.667  57  44   0.73   0.01  .667
# 7          Winnipeg Jets  20  13  6  1  27  0.675  69  53   0.55  -0.25  .675
# 8     Colorado Avalanche  18  11  6  1  23  0.639  55  42   0.82   0.10  .611
# 9    Washington Capitals  21  12  5  4  28  0.667  73  69   0.03  -0.16  .595
# 10   Tampa Bay Lightning  19  14  4  1  29  0.763  69  39   1.53  -0.05  .737
# 11     Los Angeles Kings  20   9  7  4  22  0.550  60  56   0.38   0.18  .450
# 12    Montreal Canadiens  20   9  6  5  23  0.575  65  60   0.16  -0.09  .500
# 13    New York Islanders  21  11  6  4  26  0.619  56  49   0.28  -0.06  .548
# 14    Chicago Blackhawks  23  12  7  4  28  0.609  73  68   0.00  -0.21  .543
# 15       Edmonton Oilers  23  14  9  0  28  0.609  79  69   0.43  -0.01  .609
# 16   Pittsburgh Penguins  20  11  8  1  23  0.575  60  65  -0.08   0.17  .475
#
#     RW   RgRec RgPt%       spend  efficiency                date_fetched
# 0   14  14-4-4  .727  82812722.0  107.131594  2021-03-01 06:40:37.743832
# 1    9   9-4-7  .625  78373558.0  108.101459  2021-03-01 06:40:37.743832
# 2   10  10-4-3  .676  82163798.0  111.787480  2021-03-01 06:40:37.743832
# 3    9   9-4-5  .639  80375446.0  115.814764  2021-03-01 06:40:37.743832
# 4    7   7-5-7  .553  79332810.0  115.983640  2021-03-01 06:40:37.743832
# 5    8   8-6-6  .550  78830512.0  116.785944  2021-03-01 06:40:37.743832
# 6    8   8-6-4  .556  80900154.0  121.289586  2021-03-01 06:40:37.743832
# 7    9   9-6-5  .575  83532360.0  123.751644  2021-03-01 06:40:37.743832
# 8   10  10-6-2  .611  80849033.0  126.524308  2021-03-01 06:40:37.743832
# 9   10  10-5-6  .619  85516834.0  128.211145  2021-03-01 06:40:37.743832
# 10  13  13-4-2  .737  98196125.0  128.697412  2021-03-01 06:40:37.743832
# 11   8   8-7-5  .525  72165528.0  131.210051  2021-03-01 06:40:37.743832
# 12   9   9-6-5  .575  80542193.0  140.073379  2021-03-01 06:40:37.743832
# 13  11  11-6-4  .619  86715252.0  140.089260  2021-03-01 06:40:37.743832
# 14   7   7-7-9  .500  85417864.0  140.259218  2021-03-01 06:40:37.743832
# 15  13  13-9-1  .587  85783331.0  140.859328  2021-03-01 06:40:37.743832
# 16   4   4-8-8  .400  82270132.0  143.078490  2021-03-01 06:40:37.743832
